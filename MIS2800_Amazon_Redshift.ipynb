# %% [markdown]
# <a href="https://colab.research.google.com/github/TaeTay/MIS2800/blob/main/MIS2800_Amazon_Redshift.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Part 1: The Business Impact (Lyft Case Study)

# %% [markdown]
# **Lyft Video**: https://aws.amazon.com/solutions/case-studies/lyft/
#
# **Watch the Lyft video and consider the following:**
#
# 1. The Innovation: How did moving from simple data storage to a Redshift data warehouse allow Lyft to transition from "just tracking rides" to "creating new products" like Lyft Line?
#
#
# 2. Real-time vs. Strategic: Lyft uses different tools for their app (OLTP) than they do for their planning (OLAP). Why can't they just use the same database for both?

# %% [markdown]
# ## YOUR ANSWERS TO PART 1 BELOW

# %% [markdown]
# Question 1: Lyft moving from simple data storage to Redshift allowed them to grow faster as a company as well as let them manage their growth. Using Redshift, Lyft was able to: analyze rider demands, detect recurring routes, find supply-demand mismatches, run experiments on given data, and more.
#
#
# Question 2: When Lyft uses OLYP for the app, they need to process millions of small+fast transactions, read/write data into and out of the table, have a fast response time, and can handle a lots of people using the app all at the same time. If any of this slows down, the app feels broken and many users will stop using it, which means Lyft looses money.
#
# When Lyft uses OLAP, they use it for analyzing data to make decions. Like trend analysis, holding massive datasets, running experiments, and so on. If OLAP is slow it's fine since Lyft is not loosing money.

# %% [markdown]
# ## Part 2: The Infrastructure (AWS Skill Builder)
#
# **Instructions**
#
#
# 1.   Create a free AWS Skill Builder account https://scribehow.com/viewer/AWS_Skillbuilder_and_Eduate__Souc1HOKQbiiJnktuVgSEQ
# 2.   Complete the "Introduction" and "Architecture" modules in AWS Skill Builder. Instructions are here: https://www.loom.com/share/530dd0536c2c44729fe9a6ed26f7f162
#
# # Answer the Questions
#
# 1. Scaling the Design: In DataCamp, we practiced Normalization. In the Redshift architecture, why is "Columnar Storage" often more important for an analyst than having perfectly normalized tables? https://docs.aws.amazon.com/redshift/latest/dg/c_columnar_storage_disk_mem_mgmnt.html
#
# 2. Speed to Insight: How does the architecture of a "Leader Node" and "Compute Nodes" change how quickly a Business Intelligence report is generated?  https://docs.aws.amazon.com/redshift/latest/dg/c_high_level_system_architecture.html

# %% [markdown]
# ## YOUR ANSWERS TO PART 2 BELOW

# %% [markdown]
# Question 1: Analyists usually ask questions that in things like 'by city' or 'per hour', which means they need more rows in a spreadsheet than columns. With columnar storage, only relevant columns are scanned, which means much faster queries. Normalized row-based designs must read entires rows (which means taking much more time since there are millions/billions of them compared to the number of columns), join multiple tables, and move much more data.
#
# Question 2: The architecture of a "Leader Node" and "Compute Nodes" lets Business Intelligence reports run in parallel instead of sequentially (inseatd of one machine scanning 1 billion rows, you have 10 machines each scanning 100 million rows simutaneously), which greatly reduces the generation time for reports.

# %% [markdown]
# ## Part 3: Strategic Reflection
#
# 1. The Management Perspective: As a future business leader, how does knowing the capabilities of a tool like Redshift change the questions you would ask your data team?
#
# 2. The ETL Bridge: Reflect on the ETL process. If you were a manager at an organization, why is the "Clean and Load" phase the most critical part of your BI strategy?

# %% [markdown]
# ## YOUR ANSWERS TO PART 3 BELOW

# %% [markdown]
# Question 1: It would change most of my questions from 'Can you make this report?' to 'How fast can we test this idea across the last few years of data we have?'. Knowing how to use a tool like Redshift would let me ask more scalable, predictive questions to shift these conversations in a more experimental direction that lets us generate a more data-driven strategy.
#
# Question 2: Because it's the critical point where the raw data gathered either becomes good data to put generate analytics on, or a very expensive waste of time. The 'Clean and Load' phase determines whether or nor data is accurate, consistent, and trustworthy (because without good data, you can't make good business decisions).
